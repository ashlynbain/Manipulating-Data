# %% [markdown]
# # Manipulating Data Into A Usable Format

# %%
#Reading the Data
#Creating Data Frame

import pandas as pd
import numpy as np

df = pd.read_csv('Practice123.csv', low_memory=False)

# %%
#The original data
df
# Out:
#      thinkBack: Stock quote and option quote for SPX on 7/23/16 23:59:59  \
# 0                                                   NaN
# 1                                            UNDERLYING
# 2                                                  Last
# 3                                               2175.03
# 4                                                   NaN
# 5                        22 JUL 16  (-1)  100 (Weeklys)
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# ...

# %%
origdata = df.copy()
df2 = origdata.iloc[:6, :]
df = origdata.iloc[6:, :]

# %%
df = df.drop(columns=['thinkBack: Stock quote and option quote for SPX on 7/23/16 23:59:59','Unnamed: 1','Unnamed: 2','Unnamed: 24','Unnamed: 25'])

# %%
df = df.rename(columns=df.iloc[0])
df = df[1:]
df = df.reset_index()
df = df.drop(columns=['index'])

# %%
df
# Out:
#      Prob.OTM Delta Gamma  Theta  Vega Volume Open.Int      Bid      Ask  \
# 0       0.00%  1.00  0.00  -0.01  0.00      0        0  1667.70  1679.90
# 1       0.00%  1.00  0.00  -0.02  0.00      0        0  1567.70  1579.90
# 2       0.00%  1.00  0.00  -0.02  0.00      0        0  1467.70  1479.90
# 3       0.00%  1.00  0.00  -0.02  0.00      0        0  1367.70  1379.90
# 4       0.00%  1.00  0.00  -0.02  0.00      0        0  1267.70  1279.90
# 5       0.00%  1.00  0.00  -0.03  0.00      0        0  1167.70  1179.90
# 6       0.00%  1.00  0.00  -0.03  0.00      0        1  1067.70  1079.90
# 7       0.00%  1.00  0.00  -0.03  0.00      0       19   967.70   979.90
# 8       0.00%  1.00  0.00  -0.03  0.00      0        0   942.70   954.90
# 9       0.00%  1.00  0.00  -0.03  0.00      0        0   917.70   929.90
# 10      0.00%  1.00  0.00  -0.03  0.00      0        0   892.70   904.90
# 11      0.00%  1.00  0.00  -0.04  0.00      0       10   867.70   879.90
# ...
